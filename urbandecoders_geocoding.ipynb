# %%
import csv
from geopy.geocoders import Nominatim

def geocode_address(address):
    geolocator = Nominatim(user_agent="geocoder_app")  # You might need to change the user_agent
    location = geolocator.geocode(address)

    if location:
        latitude = location.latitude
        longitude = location.longitude
        return latitude, longitude
    else:
        return None, None

# %%
# List of addresses with names
addresses_with_names = [
    {"name": "", "address": ""},
    
    # Add more addresses as needed
]

# %%
# Geocode each address in the list and save to CSV
with open("geocoded_addresses.csv", mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Address", "Latitude", "Longitude"])

    for item in addresses_with_names:
        name = item["name"]
        address = item["address"]

        latitude, longitude = geocode_address(address)

        writer.writerow([name, address, latitude, longitude])

print("Geocoded addresses saved to 'geocoded_addresses.csv'.")
# Out:
# Geocoded addresses saved to 'geocoded_addresses.csv'.
